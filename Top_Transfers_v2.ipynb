# %% [markdown]
# <a href="https://colab.research.google.com/github/stevemorrisbi/TopTransfers/blob/main/Top_Transfers_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploratory Analysis of the 'Top 50 biggest transfers' in Football History. This exploration looks at:
# - The highest player purchase for each year recorded in the top 50 transfers.
# - The top 5 teams who have spent the most out of all the top 50 tranfers.
# - The top 5 teams with the most sales in all of the top 50 tranfers.

# %%
import pandas as pd

# scraping web data via the url below

scraper = pd.read_html("https://en.wikipedia.org/wiki/List_of_most_expensive_association_football_transfers")


# below prints out all tables from the parsed url, assigning and index and seperating with ---- for formatting

# for i, table in enumerate(scraper):
#   print ("------------")
#   print(i)
#   print(table)

# for loop commented out above after seeing which table to retrieve

# printing first table (index 0)
scraper[0]
# Out:
#     Rank               Player                    From                   To  \
# 0      1               Neymar               Barcelona  Paris Saint-Germain
# 1      2        Kylian Mbappé                  Monaco  Paris Saint-Germain
# 2      3    Philippe Coutinho               Liverpool            Barcelona
# 3      4           João Félix                 Benfica      Atlético Madrid
# 4      5       Enzo Fernández                 Benfica              Chelsea
# 5      6    Antoine Griezmann         Atlético Madrid            Barcelona
# 6      7        Jack Grealish             Aston Villa      Manchester City
# 7      8          Declan Rice         West Ham United              Arsenal
# 8      9       Moisés Caicedo  Brighton & Hove Albion              Chelsea
# 9     10        Romelu Lukaku             Inter Milan              Chelsea
# 10    11      Ousmane Dembélé       Borussia Dortmund            Barcelona
# 11    11           Paul Pogba                Juventus    Manchester United
# 12    13      Jude Bellingham       Borussia Dortmund          Real Madrid
# 13    14          Eden Hazard                 Chelsea          Real Madrid
# 14    14    Cristiano Ronaldo             Real Madrid             Juventus
# 15    14           Harry Kane       Tottenham Hotspur        Bayern Munich
# 16    14          Gareth Bale       Tottenham Hotspur          Real Madrid
# 17    18               Antony                    Ajax    Manchester United
# 18    19    Cristiano Ronaldo       Manchester United          Real Madrid
# 19    20       Joško Gvardiol              RB Leipzig      Manchester City
# 20    20               Neymar     Paris Saint-Germain             Al Hilal
# 21    20      Gonzalo Higuaín                  Napoli             Juventus
# 22    23        Harry Maguire          Leicester City    Manchester United
# 23    24        Romelu Lukaku                 Everton    Manchester United
# 24    24         Jadon Sancho       Borussia Dortmund    Manchester United
# 25    26      Virgil van Dijk             Southampton            Liverpool
# 26    27          Kai Havertz        Bayer Leverkusen              Chelsea
# 27    28          Luis Suárez               Liverpool            Barcelona
# 28    29        Wesley Fofana          Leicester City              Chelsea
# 29    30        Romelu Lukaku       Manchester United          Inter Milan
# 30    30         Nicolas Pépé                   Lille              Arsenal
# 31    30    Kepa Arrizabalaga         Athletic Bilbao              Chelsea
# 32    30  Aurélien Tchouaméni                  Monaco          Real Madrid
# 33    30      Lucas Hernandez         Atlético Madrid        Bayern Munich
# 34    30         Darwin Núñez                 Benfica            Liverpool
# 35    36      Zinedine Zidane                Juventus          Real Madrid
# 36    37       Ángel Di María             Real Madrid    Manchester United
# 37    38          Kai Havertz                 Chelsea              Arsenal
# 38    39     Matthijs de Ligt                    Ajax             Juventus
# 39    39      Frenkie de Jong                    Ajax            Barcelona
# 40    39    Randal Kolo Muani     Eintracht Frankfurt  Paris Saint-Germain
# 41    39       Rasmus Højlund                Atalanta    Manchester United
# 42    39      James Rodríguez                  Monaco          Real Madrid
# 52  Midfielder             €70             £60     2023      [61]
# 53  Midfielder          €70[z]             £60     2023      [62]
# 54     Forward         €70[aa]           £58.3     2022      [63]

# %%
columns_to_remove = ['Ref.', 'Fee (€ million)']  # List of column names to remove

# assigning dataframe with dropped columns to a new variable
df = scraper[0].drop(columns_to_remove, axis=1)

df
# Out:
#     Rank               Player                    From                   To  \
# 0      1               Neymar               Barcelona  Paris Saint-Germain
# 1      2        Kylian Mbappé                  Monaco  Paris Saint-Germain
# 2      3    Philippe Coutinho               Liverpool            Barcelona
# 3      4           João Félix                 Benfica      Atlético Madrid
# 4      5       Enzo Fernández                 Benfica              Chelsea
# 5      6    Antoine Griezmann         Atlético Madrid            Barcelona
# 6      7        Jack Grealish             Aston Villa      Manchester City
# 7      8          Declan Rice         West Ham United              Arsenal
# 8      9       Moisés Caicedo  Brighton & Hove Albion              Chelsea
# 9     10        Romelu Lukaku             Inter Milan              Chelsea
# 10    11      Ousmane Dembélé       Borussia Dortmund            Barcelona
# 11    11           Paul Pogba                Juventus    Manchester United
# 12    13      Jude Bellingham       Borussia Dortmund          Real Madrid
# 13    14          Eden Hazard                 Chelsea          Real Madrid
# 14    14    Cristiano Ronaldo             Real Madrid             Juventus
# 15    14           Harry Kane       Tottenham Hotspur        Bayern Munich
# 16    14          Gareth Bale       Tottenham Hotspur          Real Madrid
# 17    18               Antony                    Ajax    Manchester United
# 18    19    Cristiano Ronaldo       Manchester United          Real Madrid
# 19    20       Joško Gvardiol              RB Leipzig      Manchester City
# 20    20               Neymar     Paris Saint-Germain             Al Hilal
# 21    20      Gonzalo Higuaín                  Napoli             Juventus
# 22    23        Harry Maguire          Leicester City    Manchester United
# 23    24        Romelu Lukaku                 Everton    Manchester United
# 24    24         Jadon Sancho       Borussia Dortmund    Manchester United
# 25    26      Virgil van Dijk             Southampton            Liverpool
# 26    27          Kai Havertz        Bayer Leverkusen              Chelsea
# 27    28          Luis Suárez               Liverpool            Barcelona
# 28    29        Wesley Fofana          Leicester City              Chelsea
# 29    30        Romelu Lukaku       Manchester United          Inter Milan
# 30    30         Nicolas Pépé                   Lille              Arsenal
# 31    30    Kepa Arrizabalaga         Athletic Bilbao              Chelsea
# 32    30  Aurélien Tchouaméni                  Monaco          Real Madrid
# 33    30      Lucas Hernandez         Atlético Madrid        Bayern Munich
# 34    30         Darwin Núñez                 Benfica            Liverpool
# 35    36      Zinedine Zidane                Juventus          Real Madrid
# 36    37       Ángel Di María             Real Madrid    Manchester United
# 37    38          Kai Havertz                 Chelsea              Arsenal
# 38    39     Matthijs de Ligt                    Ajax             Juventus
# 39    39      Frenkie de Jong                    Ajax            Barcelona
# 40    39    Randal Kolo Muani     Eintracht Frankfurt  Paris Saint-Germain
# 41    39       Rasmus Højlund                Atalanta    Manchester United
# 42    39      James Rodríguez                  Monaco          Real Madrid
# 43    39      Kevin De Bruyne           VfL Wolfsburg      Manchester City
# 44    45               Arthur               Barcelona             Juventus
# 45    46       Victor Osimhen                   Lille               Napoli
# 46    46                Rodri         Atlético Madrid      Manchester City
# 47    46         Thomas Lemar                  Monaco      Atlético Madrid
# 48    46       Alexander Isak           Real Sociedad     Newcastle United
# 49    46              Alisson                    Roma            Liverpool
# 50    46      Mykhailo Mudryk        Shakhtar Donetsk              Chelsea
# 51    46             Casemiro             Real Madrid    Manchester United
# 52    46   Dominik Szoboszlai              RB Leipzig            Liverpool
# 53    46        Sandro Tonali                   Milan     Newcastle United
# 54    46       Dušan Vlahović              Fiorentina             Juventus
#
#       Position Fee (£ million)     Year
# 0      Forward            £198     2017
# 1      Forward            £163  2018[b]
# 2   Midfielder         £105[c]     2018
# 3      Forward          £112.9     2019
# 4   Midfielder          £106.8     2023
# 5      Forward            £107     2019
# 6   Midfielder            £100     2021
# 7   Midfielder         £100[d]     2023
# 8   Midfielder         £100[e]     2023
# 9      Forward           £97.5     2021
# 10     Forward             £97     2017
# 11  Midfielder             £89     2016
# 12  Midfielder           £88.5     2023
# 13     Forward          £89[i]     2019
# 14     Forward             £88     2018
# 15     Forward           £86.4     2023
# 16     Forward             £86     2013
# 17     Forward             £82     2022
# 18     Forward             £80     2009
# 19    Defender             £77     2023
# 20     Forward             £77     2023
# 21     Forward           £75.3     2016
# 22    Defender             £80     2019
# 23     Forward          £75[l]     2017
# 24  Midfielder          £73[m]     2021
# 25    Defender             £75     2018
# 26  Midfielder             £71     2020
# 27     Forward             £65     2014
# 28    Defender             £70     2022
# 29     Forward             £74     2019
# 30  Midfielder             £72     2019
# 31  Goalkeeper           £71.6     2018
# 32  Midfielder           £69.4     2022
# 33    Defender             £68     2019
# 34     Forward          £64[o]     2022
# 35  Midfielder           £46.6     2001
# 36     Forward           £59.7     2014
# 37  Midfielder             £65     2023
# 38    Defender           £67.5     2019
# 39  Midfielder             £65     2019
# 40     Striker           £64.2     2023
# 41     Forward             £64     2023
# 42  Midfielder             £63     2014
# 43  Midfielder             £55     2015
# 44  Midfielder             £66     2020
# 45     Forward             £65     2020
# 46  Midfielder             £63     2019
# 47  Midfielder             £63     2018
# 48     Forward             £63     2022
# 49  Goalkeeper           £62.2     2018
# 50     Forward             £62     2023
# 51  Midfielder             £60     2022
# 52  Midfielder             £60     2023
# 53  Midfielder             £60     2023
# 54     Forward           £58.3     2022

# %%
columns_to_clean = ['Fee (£ million)', 'Year']  # List of columns to clean

# Create a new DataFrame with cleaned columns
cleaned_df = df.copy()  # Make a copy of the original DataFrame to avoid modifying it

# iterating over the two selected columns to remove any none numeric characters from
for column in columns_to_clean:
    cleaned_df[column] = cleaned_df[column].str.replace(r'\[.*?\]', '', regex=True)

# Print the cleaned DataFrame
print(cleaned_df)

# saving as a csv in case needed to develop outside of Python/Collab
cleaned_df.to_csv('highest transfers.csv', index = False)
# Out:
#     Rank               Player                    From                   To  \
# 0      1               Neymar               Barcelona  Paris Saint-Germain
# 1      2        Kylian Mbappé                  Monaco  Paris Saint-Germain
# 2      3    Philippe Coutinho               Liverpool            Barcelona
# 3      4           João Félix                 Benfica      Atlético Madrid
# 4      5       Enzo Fernández                 Benfica              Chelsea
# 5      6    Antoine Griezmann         Atlético Madrid            Barcelona
# 6      7        Jack Grealish             Aston Villa      Manchester City
# 7      8          Declan Rice         West Ham United              Arsenal
# 8      9       Moisés Caicedo  Brighton & Hove Albion              Chelsea
# 9     10        Romelu Lukaku             Inter Milan              Chelsea
# 10    11      Ousmane Dembélé       Borussia Dortmund            Barcelona
# 11    11           Paul Pogba                Juventus    Manchester United
# 25    Defender             £75  2018
# 26  Midfielder             £71  2020
# 27     Forward             £65  2014
# 28    Defender             £70  2022
# 29     Forward             £74  2019
# 30  Midfielder             £72  2019
# 31  Goalkeeper           £71.6  2018
# 32  Midfielder           £69.4  2022
# 33    Defender             £68  2019
# 34     Forward             £64  2022
# 35  Midfielder           £46.6  2001
# 36     Forward           £59.7  2014
# 37  Midfielder             £65  2023
# 38    Defender           £67.5  2019
# 39  Midfielder             £65  2019
# 40     Striker           £64.2  2023
# 41     Forward             £64  2023
# 42  Midfielder             £63  2014
# 43  Midfielder             £55  2015
# 44  Midfielder             £66  2020
# 45     Forward             £65  2020
# 46  Midfielder             £63  2019
# 47  Midfielder             £63  2018
# 48     Forward             £63  2022
# 49  Goalkeeper           £62.2  2018
# 50     Forward             £62  2023
# 51  Midfielder             £60  2022
# 52  Midfielder             £60  2023
# 53  Midfielder             £60  2023
# 54     Forward           £58.3  2022

# %%
# Creating a CSV download for the above table

# from google.colab import files

# # Download the file
# files.download('highest transfers.csv')

# %%
# importing this library to visualise data
import matplotlib.pyplot as plt

# Remove '£' sign and convert the column to numeric to perform
# The errors='coerce' parameter is used to handle any invalid values by converting them to NaN (Not a Number).
df['Fee (£ million)'] = pd.to_numeric(df['Fee (£ million)'].str.replace('£', ''), errors='coerce')

# Group by 'Team' and sum the 'Fee (£ million)' column
team_spending = df.groupby('To')['Fee (£ million)'].sum()

# Sort the teams by spending in descending order and select the top five
top_five_teams = team_spending.sort_values(ascending=False).head(5)

# Create a bar chart to visualize the spending of the top five teams
plt.figure(figsize=(10, 6))
top_five_teams.plot(kind='bar', color='darkgreen')
plt.title('Top Five Teams by Spending')
plt.xlabel('Team')
plt.ylabel('Total Spending (£ million)')
plt.xticks(rotation=45)
plt.show()

# %%
# Top signings for distinctive years out of the top 50 highest ever transfers

# Remove non-numeric characters from the "Year" column
df['Year'] = df['Year'].str.replace(r'[^0-9]', '', regex=True)

# Convert the "Year" column to a datetime data type
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# Finding the index for the maximum Fee for each year
idx = df.groupby('Year')['Fee (£ million)'].idxmax()

# Using the idxmax previous step to select specific row and extract the needed columns
result = cleaned_df.loc[idx, ['Year', 'Player','Fee (£ million)', 'To']].sort_values(by='Year')

# Rename the columns e.g 'To' to 'Club' for clarity
result.columns = ['Year', 'Player','Highest Transfers (£ million)', 'Club']

# Printing final output
print(result)
# Out:
#     Year             Player Highest Transfers (£ million)                 Club
# 35  2001    Zinedine Zidane                         £46.6          Real Madrid
# 18  2009  Cristiano Ronaldo                           £80          Real Madrid
# 16  2013        Gareth Bale                           £86          Real Madrid
# 27  2014        Luis Suárez                           £65            Barcelona
# 43  2015    Kevin De Bruyne                           £55      Manchester City
# 11  2016         Paul Pogba                           £89    Manchester United
# 0   2017             Neymar                          £198  Paris Saint-Germain
# 1   2018      Kylian Mbappé                          £163  Paris Saint-Germain
# 3   2019         João Félix                        £112.9      Atlético Madrid
# 26  2020        Kai Havertz                           £71              Chelsea
# 6   2021      Jack Grealish                          £100      Manchester City
# 17  2022             Antony                           £82    Manchester United
# 4   2023     Enzo Fernández                        £106.8              Chelsea

# %%
# Remove the '£' sign and convert the column to numeric
result['Highest Transfers (£ million)'] = result['Highest Transfers (£ million)'].str.replace('£', '').astype(float)

# Filter for the last ten years (11 entries) as includes current year
last_10_years = result.tail(11)

# Create a scatter plot (no lines)
plt.figure(figsize=(10, 6))
plt.plot(last_10_years['Year'], last_10_years['Highest Transfers (£ million)'], marker='o', linestyle='-')
plt.title('Top 10 Highest Transfers in the Last 10 Years')
plt.xlabel('Year')
plt.ylabel('Transfer Fee (£ million)')
plt.grid(True)
plt.xticks(rotation=45)

# Set y-axis ticks to go up in 10 million increments, formatted as strings
max_fee = int(max(last_10_years['Highest Transfers (£ million)']))
yticks = [str(x) for x in range(0, max_fee + 10, 10)]
plt.yticks(range(0, max_fee + 10, 10), yticks)

# Remove gridlines and customize background color
plt.grid(False)
plt.gca().set_facecolor('white')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the average spend for the 11-year periods
average_spend = last_10_years['Highest Transfers (£ million)'].mean()

# Create a scatter plot (no lines)
plt.figure(figsize=(10, 6))
plt.scatter(last_10_years['Year'], last_10_years['Highest Transfers (£ million)'], marker='o')
plt.title('Top 10 Highest Transfers in the Last 10 Years')
plt.xlabel('Year')
plt.ylabel('Transfer Fee (£ million)')

# Set y-axis ticks to go up in 10 million increments, formatted as strings
max_fee = int(max(last_10_years['Highest Transfers (£ million)']))
yticks = [str(x) for x in range(0, max_fee + 10, 10)]
plt.yticks(range(0, max_fee + 10, 10), yticks)

# Remove gridlines and customize background color
plt.grid(False)
plt.gca().set_facecolor('white')

# Plot a horizontal line at the average spend with cross-hatching
plt.axhline(average_spend, color='red', linestyle='--', label=f'Average Spend (£{average_spend:.2f})')

# Add a legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Teams who recieved the most money for players from the Top 50 all time sales - by each year

# Extract the year from the 'Year' column
df['Year'] = df['Year'].dt.year

# Group by 'Year' and 'Club' and sum the 'Fee (£ million)' column
yearly_team_spending = df.groupby(['Year', 'From'])['Fee (£ million)'].sum().reset_index()

# Find the club with the maximum total spending for each year
club_with_max_spending = yearly_team_spending.groupby('Year')['Fee (£ million)'].idxmax()

# Extract the corresponding year, maximum spend, and club
result = yearly_team_spending.loc[club_with_max_spending].sort_values(by='Year')

# Rename the columns for clarity
result.columns = ['Year', 'Club', 'Total Sales (£ million)']

# Print the result
print(result)
# Out:
#     Year               Club  Total Sales (£ million)
# 0   2001           Juventus                     46.6
# 1   2009  Manchester United                     80.0
# 2   2013  Tottenham Hotspur                     86.0
# 3   2014          Liverpool                     65.0
# 6   2015      VfL Wolfsburg                     55.0
# 7   2016           Juventus                     89.0
# 9   2017          Barcelona                    198.0
# 14  2018             Monaco                    226.0
# 19  2019    Atlético Madrid                    238.0
# 26  2020   Bayer Leverkusen                     71.0
# 28  2021        Aston Villa                    100.0
# 31  2022               Ajax                     82.0
# 46  2023         RB Leipzig                    137.0

# %%
# Top five teams by sales

# Group by 'Team' and sum the 'Fee (£ million)' column
team_sales = df.groupby('From')['Fee (£ million)'].sum()

# Sort the teams by spending in descending order and select the top five
top_five_sales_teams = team_sales.sort_values(ascending=False).head(5)

# Create a bar chart to visualize the spending of the top five teams
plt.figure(figsize=(10, 6))
top_five_sales_teams.plot(kind='bar', color='darkgreen')
plt.title('Top Five Teams by Sales')
plt.xlabel('Team')
plt.ylabel('Total Spending (£ million)')
plt.xticks(rotation=45)
plt.show()
